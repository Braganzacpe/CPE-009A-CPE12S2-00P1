# %% [markdown]
# <a href="https://colab.research.google.com/github/Braganzacpe/CPE-009A-CPE12S2-00P1/blob/main/Hands-on%20Activity%202.1%20Literals%20and%20Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# <center>
#
# **Technological Institute of the Philippines**<br>
# Computer Engineering Department<br>
# Quezon city Campus</center>
#
# ---
# <center><h4> Hands-on Activity 2.1 | Literals and Variables  </h4></center>
#
# ---
# <center>
#
# | Course: CPE 009 | Program: BSCpE |
# |--- | --- |
# | **Course Title**: Object Oriented Programming | **Date Performed:** 1/15/2025|
# | **Section**: CPE12S2  | **Date Submitted:** 1/15/2025 |
# | **Student Name** Ralph Angelov F. Braganza:  | **Instructor's Name:** Ms. Sayo |
# </center>

# %% [markdown]
# **Objective/s of the activity:**
#
# 1.   Implement literals and variables in a python program.
#
# **Intended Learning Outcome:**
#
# 1.   Write a simple program implementing literals and variables.
# 2.   Use comments and identify keywords from identifiers created by users.
#
# **Discussion:**
#
# Discuss the use of variables, constants and literals in a python program.
#
# **Materials and Equipment:**
#
# 1.   Functioning Computer with an OS
# 2.   Google Colab

# %% [markdown]
# **Procedure**
#
# Tasks:
# A teacher wants to calculate the final grade in a CpE course and want to write it in a python program. The following are the requirements:
#
# 1. PRELIM GRADE = 50% Prelim Exam + 50% Prelim Class Standing (CS)
# 2. PRELIM CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
# 3. MIDTERM GRADE = 1/3 of PRELIM GRADE + 2/3 of (50% Midterm Exam + 50% Midterm Class Standing (CS))
# 4. MIDTERM CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
# 5. FINAL GRADE = 1/3 of MIDTERM GRADE + 2/3 of (50% Final Exam + 50% Final Class Standing (CS))
# 6. FINAL CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
# 7. HOAs, Quizzes and Assignments are inputted as average of all submissions and are out of 100%.
# 8. Major exams are inputted out of 100%.
# 9. Show the codes that successfully run the program.
# 10. Provide comments or documentation strings for your program.

# %%
student_count = 1 #student counter
while student_count <= 3: #loops only 3 times
  print("")
  print("Student ",student_count)
  print("Prelim")
  #PRELIM CS
  PHOA = float(input("Enter Prelim Hands-on Activity: "))
  PQUIZ = float(input("Enter Prelim Quiz: "))
  PAS = float(input("Enter Prelim Assignment: "))
  PCS = PHOA*.5 + PQUIZ*.3 + PAS*.2
  print("Prelim CS is: ", PCS)

  #PRELIM EXAM
  PEX = float(input("Enter Prelim Exam: "))

  #PRELIM GRADE
  PG = PEX*.5 + PCS*.5
  print("Prelim Grade is: ", PG)

  print("")
  print("Midterm")
  #MIDTERM CS
  MHOA = float(input("Enter Midterm Hands-on Activity: "))
  MQUIZ = float(input("Enter Midterm Quiz: "))
  MAS = float(input("Enter Midterm Assignment: "))
  MCS = MHOA*.5 + MQUIZ*.3 + MAS*.2
  print("Midterm CS is: ", MCS)

  #MIDTERM EXAM
  MEX = float(input("Enter Midterm Exam: "))

  #MIDTERM GRADE
  MG = 1/3*PG + 2/3*(MEX*.5 + MCS*.5)
  print("Midterm Grade is: ", MG)

  print("")
  print("Finals")
  #FINAL CS
  FHOA = float(input("Enter Final Hands-on Activity: "))
  FQIZ = float(input("Enter Final Quiz: "))
  FAS = float(input("Enter Final Assignment: "))
  FCS = FHOA*.5 + FQIZ*.3 + FAS*.2
  print("Final CS is: ", FCS)

  #FINAL EXAM
  FEX = float(input("Enter Final Exam: "))

  #FINAL GRADE
  FG = 1/3*MG + 2/3*(FEX*.5 + FCS*.5)
  print("Final Grade is: ", FG)
  student_count += 1
# Out:
# Student  1
# Prelim
# Enter Prelim Hands-on Activity: 100
# Enter Prelim Quiz: 89
# Enter Prelim Assignment: 76
# Prelim CS is:  91.9
# Enter Prelim Exam: 75
# Prelim Grade is:  83.45
#
# Midterm
# Enter Midterm Hands-on Activity: 100
# Enter Midterm Quiz: 88
# Enter Midterm Assignment: 83
# Midterm CS is:  93.0
# Enter Midterm Exam: 67
# Midterm Grade is:  81.14999999999999
#
# Finals
# Enter Final Hands-on Activity: 100
# Enter Final Quiz: 88
# Enter Final Assignment: 100
# Final CS is:  96.4
# Enter Final Exam: 78
# Final Grade is:  85.18333333333334
#
# Student  2
# Prelim
# Enter Prelim Hands-on Activity: 100
# Enter Prelim Quiz: 84
# Enter Prelim Assignment: 77
# Prelim CS is:  90.60000000000001
# Enter Prelim Exam: 88
# Prelim Grade is:  89.30000000000001
#
# Midterm
# Enter Midterm Hands-on Activity: 100
# Enter Midterm Quiz: 89
# Enter Midterm Assignment: 78
# Midterm CS is:  92.30000000000001
# Enter Midterm Exam: 68
# Midterm Grade is:  83.2
#
# Finals
# ...

# %% [markdown]
# **Supplementary Activity**:
#
#
# Test 3 students from the program you created.
#
# 1. The program should show the name of the student, the PRELIM, MIDTERM and FINAL grades.
# 2. Convert the final grade into the T.I.P.s numerical grade. Please refer to the grading system.

# %%
student_count = 0 #Student Counter
while student_count < 3: #Up to 3 students data to be inputted
  student_name = input("Enter Student Name: ")
  PG = float(input("Enter Prelim Grade: "))
  MG = float(input("Enter Midterm Grade: "))
  FG = float(input("Enter Final Grade: "))
  #T.I.P Grading System
  if 99 <= FG <= 100:
    print("Grade: 1.00 Excellent")
  elif 95 < FG < 99:
    print("Grade: 1.25 Superior")
  elif 92 < FG < 96:
    print("Grade: 1.50 Meritourious")
  elif 89 < FG < 93:
    print("Grade: 1.75 Very Good")
  elif 86 < FG < 90:
    print("Grade: 2.00 Good")
  elif 83 < FG < 87:
    print("Grade: 2.25 Very Satisfactory")
  elif 80 < FG < 84:
    print("Grade: 2.50 Satisfactory")
  elif 77 < FG < 81:
    print("Grade: 2.75 Fair")
  elif 74 < FG < 78:
    print("Grade: 3.00 Passing!")
  else:
    print("Grade: 5.00 Failed")
  print("\n")
  student_count += 1 #Increments 1 until the < 3 condition is met
# Out:
# Enter Student Name: Ralph
# Enter Prelim Grade: 100
# Enter Midterm Grade: 99
# Enter Final Grade: 98
# Grade: 1.25 Superior
#
#
# Enter Student Name: Kenji
# Enter Prelim Grade: 100
# Enter Midterm Grade: 100
# Enter Final Grade: 100
# Grade: 1.00 Excellent
#
#
# Enter Student Name: Christine
# Enter Prelim Grade: 67
# Enter Midterm Grade: 69
# Enter Final Grade: 90
# Grade: 1.75 Very Good

# %% [markdown]
# **Conclusion**:
#
# In this activity I've learned to improve my computation skills and implement these computations into code. I am still getting used to Python, so making the loop for the 3 students for task 1 and the supplementary was quite a challenge to make because I came from coding in C++. What took the most time for me was the T.I.P. grading system, and honestly, it was simple; I just didn't have enough brain capacity to imagine it out into code. Nonetheless, I completed everything after figuring out the first block of code; then it was just copy-paste from there. Overall, this activity was a good exercise for me to develop my coding skills even further, and I hope in the future I can improve to become faster and more logical when coding.
