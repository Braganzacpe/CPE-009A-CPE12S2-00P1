# %% [markdown]
# <a href="https://colab.research.google.com/github/Braganzacpe/CPE-009A-CPE12S2-00P1/blob/main/Control_Structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# If Statement

# %%
a = 69
b = 67
if b<a:
  print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# Elif Statements

# %%
a = 12
b = 12
if b > a:
  print("b is greater than a")
elif a==b:
  print ("a and b are equal")
# Out:
# a and b are equal

# %% [markdown]
# Else Statement

# %%
a = 200
b = 33
if b > a:
  print("b is greater than a")
elif a==b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# Short Hand If Statement

# %%
if a > b: print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# Short Hand If..Else Statement

# %%
a = 2
b = 330
print("A") if a > b else print("B")
# Out:
# B

# %% [markdown]
# And-both conditions are true

# %%
a = 200
b = 33
c = 500
if a > b and c > a:
  print("Both conditions are True")
# Out:
# Both conditions are True

# %% [markdown]
# Or - at least one of the condition is true

# %%
a = 200
b = 33
c = 500
if a > b and c > a:
  print("At least one of the conditions is True")
# Out:
# At least one of the conditions is True

# %% [markdown]
# Nested If

# %%
#+5
x= int(input("Enter Number:"))
if x > 10:
  print("Above 10")
  if x > 20:
    print("and also above 20!")
    if x > 30:
      print("and also above 30!")
      if x > 40:
        print ("and also above 40!")
        if x > 50:
          print("and also above 50!")

        else:
          print("but not above 50.")
      else:
        print("but not above 40.")
    else:
      print("but not above 30.")
  else:
    print("but not above 20.")
else:
  print("but not above 10.")
# Out:
# Enter Number:52
# Above 10
# and also above 20!
# and also above 30!
# and also above 40!
# and also above 50!

# %% [markdown]
# Supplementary Activity: (Plus 5)

# %%
#+5
grade = int(input("Enter Grade: "))
if grade > 75:
  print("Passed")
elif grade == 74:
  print("Remedial")
elif grade < 0:
  print("Grade not accepted")
else:
  print("Failed")
# Out:
# Enter Grade: -4
# Grade not accepted
