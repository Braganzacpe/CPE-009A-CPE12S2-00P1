# %% [markdown]
# <a href="https://colab.research.google.com/github/Braganzacpe/CPE-009A-CPE12S2-00P1/blob/main/%20Hands-on%20Activity%201.1%20Literals%2C%20Operators%2C%20and%20Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assigning variables of different data types in Python

# %%
#1
value = 5
print(value)
# Out:
# 5

# %%
#2
type(value)
# Out:
# int

# %%
#3
value = 5.0
print(5.0)
# Out:
# 5.0

# %%
#4
type(value)
# Out:
# float

# %%
#5
#a.
value = 2+3j
print(value)
# Out:
# (2+3j)

# %%
#a type
type(value)
# Out:
# complex

# %%
#b
value = 'Hello World'
print(value)
# Out:
# Hello World

# %%
#b type
type(value)
# Out:
# str

# %%
#c
value = "Hello World"
print(value)
# Out:
# Hello World

# %%
#c type
type(value)
# Out:
# str

# %%
#d
value = True
print(value)
# Out:
# True

# %%
#d type
type(value)
# Out:
# bool

# %%
#e
value = False
print(value)
# Out:
# False

# %%
#e type
type(value)
# Out:
# bool

# %%
#f
value = [1,2,3,4,5]
print(value)
# Out:
# [1, 2, 3, 4, 5]

# %%
#f type
type(value)
# Out:
# list

# %%
#g
value = (1,2,3,4,5)
print(value)
# Out:
# (1, 2, 3, 4, 5)

# %%
#g type
type(value)
# Out:
# tuple

# %%
#h
value = {'ralph': 'Ralph_braganza'}
print(value)
# Out:
# {'ralph': 'Ralph_braganza'}

# %%
#h type
type(value)
# Out:
# dict

# %%
#i
value = None
print(value)
# Out:
# None

# %%
#i type
type(value)
# Out:
# NoneType

# %%
#6
value = 5
print(value)
# Out:
# 5

# %%
#7
value2 = -6
print(value2)
# Out:
# -6

# %% [markdown]
# Performing Operations with Python

# %%
#1
print(value+value2)
# Out:
# -1

# %%
#2
value, value2 = 5, -6

# %%
#a
value, value2 = 5.0, 6
print(value,value2)
# Out:
# 5.0 6

# %%
#b
value, value2 = -5, 6.1
print(value,value2)
# Out:
# -5 6.1

# %%
#c
value, value2 = "Hello", 'world'
print(value,value2)
# Out:
# Hello world

# %%
#d
value, value2 = [1,2,3], [4,5,6]
print(value,value2)
# Out:
# [1, 2, 3] [4, 5, 6]

# %%
#e
value, value2 = (1,2,3), (4,5,6)
print(value,value2)
# Out:
# (1, 2, 3) (4, 5, 6)

# %%
#f
value, value2 = {"name":"Ralph"}, {"age":20}
print(value,value2)
# Out:
# {'name': 'Ralph'} {'age': 20}

# %%
#3
#a
value, value2 = 30, 4
print(value,value2)
# Out:
# 30 4

# %%
#b
print(value*value2)
# Out:
# 120

# %%
#c
print(value2**value2)
# Out:
# 256

# %%
#d
print(value2**3)
# Out:
# 64

# %%
#e
print(value*value2+value2**2+1)
# Out:
# 137

# %%
#f
print(value/value2)
# Out:
# 7.5

# %%
#g
print(value%value2)
# Out:
# 2

# %% [markdown]
# Assigning Input Data to a Variable:

# %%
#1-5
name = input("Enter your name: ")
weight = float(input("Enter your weight(kg): "))
height = float(input("Enter your meters(m): "))

bmi = weight/(height**2)
print("Your BMI is: ",bmi)
# Out:
# Enter your name: Ralph Angelov F. Braganza
# Enter your weight(kg): 60
# Enter your meters(m): 1.74
# Your BMI is:  19.817677368212443

# %%
#6
print("Name: ",name)
print("Weight: ",weight)
print("Height: ",height)
print("BMI: ",bmi)
# Out:
# Name:  Ralph Angelov F. Braganza
# Weight:  60.0
# Height:  1.74
# BMI:  19.817677368212443

# %% [markdown]
# Supplementary Activity:

# %%
#1. Write the Python equivalent code of the following C code:
base = float(input("Enter base value: "))
height = float(input("Enter height value: "))
area = 1/2*(base*height)
print("The area of the traingle is: ", area)
# Out:
# Enter base value: 6
# Enter height value: 7
# The area of the traingle is:  21.0

# %%
#2 Write a program that would convert Celsius to Fahrenheit given the formula: F = (C × 9/5) + 32
Celsius = float(input("Enter Celsius Value: "))
Fahrenheit = (Celsius*9/5)+32
print("Fahrenheight is: ",Fahrenheit )
# Out:
# Enter Celsius Value: 99
# Fahrenheight is:  210.2

# %%
#3. Write a program that can determine the distance between two points given the coordinates using the

x1 = float(input("Enter the value of x1: "))
x2 = float(input("Enter the value of x2: "))
y1 = float(input("Enter the value of y1: "))
y2 = float(input("Enter the value of y2: "))

computation = (x2-x1)**2+(y2-y1)**2
d = computation**0.5
print("The distance between two points is: ",d)
# Out:
# Enter the value of x1: 6
# Enter the value of x2: 7
# Enter the value of y1: 6
# Enter the value of y2: 9
# The distance between two points is:  3.1622776601683795
