# %% [markdown]
# <a href="https://colab.research.google.com/github/Braganzacpe/CPE12S2-CPE-003A/blob/main/Python_Fundementals_(BRAGANZA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Indentation

# %%
if 5 > 2:
  print("Five is greater than two!")
# Out:
# Five is greater than two!

# %% [markdown]
# Python Comments

# %%
#This is a comment
print("Hello, CPE!")
# Out:
# Hello, CPE!

# %% [markdown]
# Python Naming Conventions

# %%
size = float(10)
size_2 = int(5)
Size = "small"
print(size)
print(size_2)
print(Size)
# Out:
# 10.0
# 5
# small

# %% [markdown]
# Python Variable

# %%
x = 1
a, b = 0, -1
a, b, c = 0, -1 ,2
b = "Sally" #This is a type of string
print (a, b, c)
# Out:
# 0 Sally 2

# %% [markdown]
# Python Casting

# %%
b = "sally" #This is a type of string
b =int(4)
print(b)

b=float(4)
print(b)
# Out:
# 4
# 4.0

# %% [markdown]
# Python Type() function

# %%
x = 5
y = "John"
print (type(x))
print (type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# Python "Double quote" or 'Single quotes'

# %%
y = "John"
y = 'John'
print(y)
# Out:
# John

# %% [markdown]
# Python Case sensitive

# %%
a = 4
A = "Sally"
#A will not overwrite a
print(a,A)
# Out:
# 4 Sally

# %% [markdown]
# Python Multiple Variables

# %%
x,y,z = "one", "two", "three"
print(x)
print(y)
print(z)
# Out:
# one
# two
# three

# %% [markdown]
# One Value to Multiple Variables

# %%
x = y = z = "four"
print(x)
print(y)
print(z)
# Out:
# four
# four
# four

# %% [markdown]
# Output Variables

# %%
x = "enjoying"
print("Python programming is " +x)
# Out:
# Python programming is enjoying

# %% [markdown]
# Other way:

# %%
x = "Pythong is "
y = "enjoying"
z= x + y
print(z)
# Out:
# Pythong is enjoying

# %% [markdown]
# Arithmetic Operations

# %%
#Additon
x =5
y = 3
print(x+y)

x =5
y = 3
sum = x+y
sum

#Subtraction
print(x-y)

#Multiplication
print(x*y)

#Division
print(x/y)

#Modulus
print(x%y)

#Exponentiation
print(x**y)

#Floordivision
print(x//y)
# Out:
# 8
# 2
# 15
# 1.6666666666666667
# 2
# 125
# 1

# %% [markdown]
# Assignment Operator

# %%
#
s=1
s+=3 #same as s = s + 3 > s = 1 + 3 > s = 4
print(s)

#+=
s=1
s+=3
print(s)

#-=
s=1
s-=3
print(s)

#*=
s=1
s*=3
print(s)

#/=
s=1
s/=3
print(s)

#%=
s=1
s%=3
print(s)

#**=
s=1
s**=3
print(s)

#//=
s=1
s//=3
print(s)

#&=
s=1
s&=3
print(s)

#|=
s=1
s|=3
print(s)

#^=
s=1
s^=3
print(s)

#>>=
s=1
s>>=3
print(s)

#<<=
s=1
s<<=3
print(s)
# Out:
# 4
# 4
# -2
# 3
# 0.3333333333333333
# 1
# 1
# 0
# 1
# 3
# 2
# 0
# 8

# %% [markdown]
# Comparison Operators

# %%
t = 1
u = 2

#== Equal
print (t==u)
#!= Not Equal
print (t!=u)
#> Greater Than
print (t>u)
#< Less Than
print (t<u)
#>= Greater than or equal to
print (t>=u)
#<= Less Than or equal to
print (t<=u)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# Logical Operator

# %%
t = 2

#and
print(t < 5 and t < 10)
#or
print(t < 5 or t < 4)
#not
print(not(t < 5 and t < 10))
# Out:
# True
# True
# False

# %% [markdown]
# Identitiy Operators

# %% [markdown]
# Bitwise Operators

# %%
v = 2

# & AND
print(1&2)
print(15&15)

# | OR
print(v<<1)

# ^ XOR
print(v^1)

# ~  NOT
print(~v)

# << ZERO FILL LEFT SHIFT
print(v<<1)
print(v<<2)

# >> SIGNED RIGHT SHIFT
print(v>>1)
# Out:
# 0
# 15
# 4
# 3
# -3
# 4
# 8
# 1
