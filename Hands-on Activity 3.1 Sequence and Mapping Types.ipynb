# %% [markdown]
# <a href="https://colab.research.google.com/github/Braganzacpe/CPE-009A-CPE12S2-00P1/blob/main/Hands-on%20Activity%203.1%20Sequence%20and%20Mapping%20Types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SW#1 - Prelim

# %% [markdown]
# Name: Braganza, Ralph Angelov F.
#
# Section: CPE12S2
#
# Date performed: February 26, 2026

# %% [markdown]
# Procedure:

# %%
#1. Create a variable numberlist and assign it the value of [5,4,2,1,3].
numberlist= [5,4,2,1,3]

# %%
#2. Print the following values below:
#a.
len(numberlist)
# Out:
# 5

# %%
#b.
numberlist[0]
# Out:
# 5

# %%
#c.
numberlist[1]
# Out:
# 4

# %%
#d.
numberlist[2]
# Out:
# 2

# %%
#e.
numberlist[3]
# Out:
# 1

# %%
#f.
numberlist[4]
# Out:
# 3

# %%
#g.
numberlist[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_831/3832440855.py in <cell line: 0>()
#       1 #g.
# ----> 2 numberlist[5]
#
# IndexError: list index out of range

# %%
#h.
numberlist[-1]
# Out:
# 3

# %%
#i.
numberlist[-2]
# Out:
# 1

# %%
#j.
numberlist[-3]
# Out:
# 2

# %%
#k.
numberlist[-4]
# Out:
# 4

# %%
#l.
numberlist[-5]
# Out:
# 5

# %%
#m.
numberlist[-6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_831/2900895290.py in <cell line: 0>()
#       1 #m.
# ----> 2 numberlist[-6]
#
# IndexError: list index out of range

# %% [markdown]
# **Observation:**
# - The length of the list is 5.
#
# - Positive indexing starts from 0 up to 4.
#
# - Negative indexing starts from -1 (last element) to -5.
#
# - Accessing an index outside the range (like 5 or -6) produces an IndexError.
#
# - Python lists are zero-indexed.

# %% [markdown]
# ## <a id="procedures">Procedures</a>

# %%
#1. Create a variable numberlist and assign it the value of [5,4,2,1,3].
numberlist= [5,4,2,1,3]

# %%
#2. Print the following values below:
#a.
len(numberlist)
# Out:
# 5

# %%
#b.
numberlist[0]
# Out:
# 5

# %%
#c.
numberlist[1]
# Out:
# 4

# %%
#d.
numberlist[2]
# Out:
# 2

# %%
#e.
numberlist[3]
# Out:
# 1

# %%
#f.
numberlist[4]
# Out:
# 3

# %%
#g.
numberlist[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_831/3832440855.py in <cell line: 0>()
#       1 #g.
# ----> 2 numberlist[5]
#
# IndexError: list index out of range

# %%
#h.
numberlist[-1]
# Out:
# 3

# %%
#i.
numberlist[-2]
# Out:
# 1

# %%
#j.
numberlist[-3]
# Out:
# 2

# %%
#k.
numberlist[-4]
# Out:
# 4

# %%
#l.
numberlist[-5]
# Out:
# 5

# %%
#m.
numberlist[-6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_831/2900895290.py in <cell line: 0>()
#       1 #m.
# ----> 2 numberlist[-6]
#
# IndexError: list index out of range

# %% [markdown]
# 3. **Observation:**
# - The length of the list is 5.
#
# - Positive indexing starts from 0 up to 4.
#
# - Negative indexing starts from -1 (last element) to -5.
#
# - Accessing an index outside the range (like 5 or -6) produces an IndexError.
#
# - Python lists are zero-indexed.

# %%
#4. Create a variable named itemlist and assign it the value of [1,-2.0,[1,2,3],"Word"]
itemlist = [1,-2.0,[1,2,3],"Word"]

# %%
#a.
len(itemlist)
# Out:
# 4

# %%
#b.
itemlist [0]
# Out:
# 1

# %%
#c.
itemlist [1]
# Out:
# -2.0

# %%
#d.
itemlist [2]
# Out:
# [1, 2, 3]

# %%
#e.
itemlist [3]
# Out:
# 'Word'

# %%
#f.
len(itemlist[2])
# Out:
# 3

# %%
#g.
itemlist [2][0]
# Out:
# 1

# %%
#h.
itemlist [2][1]
# Out:
# 2

# %%
#i.
itemlist [2][2]
# Out:
# 3

# %%
#j.
itemlist [-1]
# Out:
# 'Word'

# %%
#k.
itemlist [-2]
# Out:
# [1, 2, 3]

# %%
#l.
itemlist [-3]
# Out:
# -2.0

# %%
#m.
itemlist [-4]
# Out:
# 1

# %%
#n.
len(itemlist[-2])
# Out:
# 3

# %%
#o.
itemlist[-2][0]
# Out:
# 1

# %%
#p.
itemlist[-2][1]
# Out:
# 2

# %%
#q.
itemlist[-2][2]
# Out:
# 3

# %%
#r.
itemlist[-2][-3]
# Out:
# 1

# %%
#s.
itemlist[-2][-2]
# Out:
# 2

# %%
#t.
itemlist[-2][-1]
# Out:
# 3

# %% [markdown]
# **6. Observaton**
# - A list can contain different data types (integer, float, list, string).
#
# - Lists can contain nested lists (a list inside another list).
#
# - You can access elements inside a nested list using double indexing like:
#
# **What does lens() do?**
# The len() function returns the total number of elements in a list (or items in other collections like strings, tuples, etc.).

# %%
#1. Create a new variable longlist and assign it the value of numberlist + itemlist.
longlist = numberlist + itemlist

# %%
#2. Print the following values below and write your observation for each of the following sub-groups (sub-headings):

#a.
len(longlist)
# Out:
# 9

# %%
#b.
longlist [:]
# Out:
# [5, 4, 2, 1, 3, 1, -2.0, [1, 2, 3], 'Word']

# %%
#c.
longlist[:9]
# Out:
# [5, 4, 2, 1, 3, 1, -2.0, [1, 2, 3], 'Word']

# %%
#d.
longlist[0:]
# Out:
# [5, 4, 2, 1, 3, 1, -2.0, [1, 2, 3], 'Word']

# %%
#e.
longlist[1:]
# Out:
# [4, 2, 1, 3, 1, -2.0, [1, 2, 3], 'Word']

# %%
#f.
longlist[2:]
# Out:
# [2, 1, 3, 1, -2.0, [1, 2, 3], 'Word']

# %% [markdown]
# **Index Slicing with Range **

# %%
#g.
longlist[2:5]
# Out:
# [2, 1, 3]

# %%
#h.
longlist[5:2]
# Out:
# []

# %%
#i.
longlist[8:]
# Out:
# ['Word']

# %%
#j.
longlist[9:]
# Out:
# []

# %% [markdown]
# **Index Slicing using Negative Indices**

# %%
#k.
longlist[-9:]
# Out:
# [5, 4, 2, 1, 3, 1, -2.0, [1, 2, 3], 'Word']

# %%
#l.
longlist[-8:]
# Out:
# [4, 2, 1, 3, 1, -2.0, [1, 2, 3], 'Word']

# %%
#m.
longlist[-8:-7]
# Out:
# [4]

# %%
#n.
longlist[-1:]
# Out:
# ['Word']

# %% [markdown]
# **Other properties of Index Slicing**

# %%
#o.
longlist[10:20]
# Out:
# []

# %%
#p.
longlist[-7:5]
# Out:
# [2, 1, 3]

# %% [markdown]
# **Index Slicing with Step parameter**

# %%
#q.
longlist[::1]
# Out:
# [5, 4, 2, 1, 3, 1, -2.0, [1, 2, 3], 'Word']

# %%
#r.
longlist[::2]
# Out:
# [5, 2, 3, -2.0, 'Word']

# %%
#s.
longlist[1:8:2]
# Out:
# [4, 1, 1, [1, 2, 3]]

# %%
#t.
longlist[9:1:-1]
# Out:
# ['Word', [1, 2, 3], -2.0, 1, 3, 1, 2]

# %%
#u.
longlist[-1::1]
# Out:
# ['Word']

# %%
#v.
longlist[-1::-1]
# Out:
# ['Word', [1, 2, 3], -2.0, 1, 3, 1, 2, 4, 5]

# %% [markdown]
# **Observation**
# - The start index is included, but the stop index is excluded.
#
# - If start > stop and step is positive → result is empty.
#
# - Negative indices count from the end.
#
# - Step controls skipping and direction.
#
# - Python slicing never throws an index error — it safely adjusts the range.
#
# - [::-1] is the easiest way to reverse a list.

# %% [markdown]
# **List Methods and the Mutable Property of Lists**

# %%
numberlist2 = numberlist

# %%
print(numberlist)
# Out:
# [5, 4, 2, 1, 3]

# %%
print(numberlist2)
# Out:
# [5, 4, 2, 1, 3]

# %%
numberlist[0] = 6

# %%
print(numberlist)
# Out:
# [6, 4, 2, 1, 3]

# %%
print(numberlist2)
# Out:
# [6, 4, 2, 1, 3]

# %%
numberlist2 = numberlist.copy()

# %%
print(numberlist2)
# Out:
# [6, 4, 2, 1, 3]

# %%
numberlist[0] = 5

# %%
print(numberlist)
# Out:
# [5, 4, 2, 1, 3]

# %%
print(numberlist2)
# Out:
# [6, 4, 2, 1, 3]

# %% [markdown]
# **Observation**
#
# numberlist2 did NOT change this time and that is because .copy() creates a new independent list. Lists can be changed after creation and modifying elements changes the actual object in memory. numberlist2 = numberlist creates a reference where both variables point to the same memory location and changes. However, numberlist2 = numberlist.copy() creates a new separate list and stores it in a different memory location where it changes in one and does NOT affect the other.

# %% [markdown]
# **Exploring some List Functions and Methods**

# %%
print(numberlist)
# Out:
# [5, 4, 2, 1, 3]

# %%
numberlist.append(6)

# %%
print(numberlist)
# Out:
# [5, 4, 2, 1, 3, 6]

# %%
numberlist.pop()
# Out:
# 6

# %%
print(numberlist)
# Out:
# [5, 4, 2, 1, 3]

# %%
numberlist.sort()

# %%
print(numberlist)
# Out:
# [1, 2, 3, 4, 5]

# %%
itemlist.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_831/1809657090.py in <cell line: 0>()
# ----> 1 itemlist.sort()
#
# TypeError: '<' not supported between instances of 'list' and 'float'

# %%
min(numberlist)
# Out:
# 1

# %%
max(numberlist)
# Out:
# 5

# %%
min(numberlist)
# Out:
# 1

# %%
print(longlist.count(1))
# Out:
# [5, 4, 2, 1, 3, 1, -2.0, [1, 2, 3], 'Word']

# %%
print(longlist[7].count(1))
# Out:
# 1

# %% [markdown]
# **The in operator**

# %%
print(3 in longlist)
# Out:
# True

# %%
print(15 in longlist)
# Out:
# False

# %%
num = int(input("Enter a number: "))
if num in longlist:
  print("The number is in longlist")
else:
  print("The number is not in longlist")
# Out:
# Enter a number: 10
# The number is not in longlist

# %% [markdown]
# **Observation**
# - The in operator checks whether a value exists inside a sequence (like a list).
#
# - It returns a Boolean value: True or False.
#
# - It does not modify the list.
#
# - It only checks for exact matches.

# %% [markdown]
# **Using a list in an iterative statement**

# %%
for item in longlist:
  print(item)
# Out:
# 5
# 4
# 2
# 1
# 3
# 1
# -2.0
# [1, 2, 3]
# Word

# %%
i=0
while i<len(longlist):
  print(longlist[i])
  i+=1
# Out:
# 5
# 4
# 2
# 1
# 3
# 1
# -2.0
# [1, 2, 3]
# Word

# %% [markdown]
# **Strings**

# %%
message = "Hello World"

# %%
print(message)
# Out:
# Hello World

# %%
print(len(message))
# Out:
# 11

# %%
#POSITIVE
print(message[0])  # H
print(message[1])  # E
print(message[2])  # L
print(message[3])  # L
print(message[4])  # O
# Out:
# H
# e
# l
# l
# o

# %%
#NEGATIVE
print(message[-11])  # H
print(message[-10])  # E
print(message[-9])   # L
print(message[-8])   # L
print(message[-7])   # O
# Out:
# H
# e
# l
# l
# o

# %%
print(message[0] + message[1] + message[2] + message[3] + message[4])
# Out:
# Hello

# %%
print(message[0:5])
# Out:
# Hello

# %%
print(message[6:11])
# Out:
# World

# %% [markdown]
# **String Methods**

# %%
print(message.upper())
# Out:
# HELLO WORLD

# %%
print(message.lower())
# Out:
# hello world

# %%
print(message.title())
# Out:
# Hello World

# %%
print("Value 1 is {}, and value 2 is {}".format(-1, True))
# Out:
# Value 1 is -1, and value 2 is True

# %%
print(message.split(' '))
# Out:
# ['Hello', 'World']

# %%
print(message.count('l'))
# Out:
# 3

# %%
print(message.replace('World','CPE009'))
# Out:
# Hello CPE009

# %%
message = message.replace('World','CPE009')
print(message)
# Out:
# Hello CPE009

# %%
help("")
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %% [markdown]
# **Methods Used in Previous Tasks:**
#
# .upper()
#
# .lower()
#
# .title()
#
# .split()
#
# .count()
#
# .replace()
#
# .format()

# %% [markdown]
# **The in operator for Strings**

# %%
print('W' in message)
# Out:
# False

# %%
print('old' in message)
# Out:
# False

# %%
word = input("Enter a word: ")

if word in "The big brown fox jump over the lazy dog":
    print("The word is in the text")
else:
    print("The word is not in the text")
# Out:
# Enter a word: YEET!
# The word is not in the text

# %% [markdown]
# **Using a String in an iterative statement**

# %%
for character in message:
    print(character)
# Out:
# H
# e
# l
# l
# o
#
# C
# P
# E
# 0
# 0
# 9

# %%
i = 0
while i < len(message):
    print(message[i])
    i += 1
# Out:
# H
# e
# l
# l
# o
#
# C
# P
# E
# 0
# 0
# 9

# %% [markdown]
# **Tuples**

# %%
tuplelist = (1, 2, 3, 4, 5)

# %%
print(numberlist[0])  # a
# Out:
# 1

# %%
print(numberlist[1])  # b
# Out:
# 2

# %%
print(numberlist[2])  # c
# Out:
# 3

# %%
print(numberlist[3])  # d
# Out:
# 4

# %%
print(numberlist[4])  # e
# Out:
# 5

# %%
print(numberlist[5]) # f
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_831/2156425639.py in <cell line: 0>()
# ----> 1 print(numberlist[5]) # f
#
# IndexError: list index out of range

# %%
print(tuplelist + (1, 2, 3))
# Out:
# (1, 2, 3, 4, 5, 1, 2, 3)

# %%
tuplelist[0] = 15
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_831/487520841.py in <cell line: 0>()
# ----> 1 tuplelist[0] = 15
#
# TypeError: 'tuple' object does not support item assignment

# %%
tuplelist[1:4]
# Out:
# (2, 3, 4)

# %%
for num in tuplelist:
    print(num)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# **Dictionaries**

# %%
contactinfo = {
    'id': 1,
    'first_name': 'John',
    'last_name': 'Doe',
    'contact_number': '09060611233'
}

# %%
print(contactinfo['id']) # a
# Out:
# 1

# %%
print(contactinfo['first_name']) # b
# Out:
# John

# %%
print(contactinfo['last_name']) # c
# Out:
# Doe

# %%
print(contactinfo['contact_number']) # d
# Out:
# 09060611233

# %%
print(contactinfo['age']) # e ERROR NONEXISTENT
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_831/884092210.py in <cell line: 0>()
# ----> 1 print(contactinfo['age'])
#
# KeyError: 'age'

# %%
for k, v in contactinfo:
    print(k)
# Out:
# i
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_831/147214779.py in <cell line: 0>()
# ----> 1 for k, v in contactinfo:
#       2     print(k)
#
# ValueError: too many values to unpack (expected 2)

# %%
for k, v in contactinfo.items():
    print(k, v)
# Out:
# id 1
# first_name John
# last_name Doe
# contact_number 09060611233

# %%
contactinfo['id'] = 2
contactinfo['first_name'] = 'Max'

# %%
print(contactinfo)
# Out:
# {'id': 2, 'first_name': 'Max', 'last_name': 'Doe', 'contact_number': '09060611233'}

# %% [markdown]
# ## <a id="supplementary_activities">Supplementary Activity</a>

# %% [markdown]
# **Tasks**

# %% [markdown]
# Distance Formula
# 1. Make a program that would calculate the distance between two points given a list of coordinates. Use the distance  formula.

# %%
coordinates_list = [(1, 1), (2, 3)]

(x1, y1) = coordinates_list[0]
(x2, y2) = coordinates_list[1]

distance = ((x2 - x1)**2 + (y2 - y1)**2)**0.5

print("Distance between the points:", distance)
# Out:
# Distance between the points: 2.23606797749979

# %% [markdown]
# Simple Word Filter
#
# 2. For a given string input, replace all the words “stupid” with an asterisk * equal to the length of the string. The new  string value should be displayed with the asterisks.

# %%
text = input("Enter a sentence: ")

filtered_text = text.replace("stupid", "*" * len("stupid"))

print("Filtered sentence:", filtered_text)
# Out:
# Enter a sentence: This guy is hella stupid
# Filtered sentence: This guy is hella ******

# %% [markdown]
# Phonebook
#
# 3. Create a simple phonebook program that can read from a list of dictionaries. The program should be able to display a  person’s name, contact, and address based from a user input which is the id of the record.

# %%
phonebook = [
    {'id': 1, 'name': 'Ralph Braganza', 'contact': '676767', 'address': ' 43D J.P Rizal'},
    {'id': 2, 'name': 'Andrei Calizo', 'contact': '696969', 'address': '69 Amihan'},
    {'id': 3, 'name': 'Frazier Lag', 'contact': '10101001', 'address': ' 67 Mary Grace'}
]

user_id = int(input("Enter the ID of the person: "))

found = False
for person in phonebook:
    if person['id'] == user_id:
        print("Name:", person['name'])
        print("Contact:", person['contact'])
        print("Address:", person['address'])
        found = True
        break
#This is for error checking
if not found:
    print("Record with ID", user_id, "not found.")
# Out:
# Enter the ID of the person: 3
# Name: Frazier Lag
# Contact: 10101001
# Address:  67 Mary Grace

# %% [markdown]
# ## <a id="conclusion">Conclusion</a>

# %% [markdown]
# In this activity, I learned how to use different data types and structures in Python, such as lists, tuples, dictionaries, and strings. I learned how to access and modify them using indexes, slices, and loops. I also learned how to use strings to perform operations such as converting letters to capital case, counting letters, and replacing words. I also learned how to use dictionaries and store information in them with keys and values. I even learned how to apply math operations in Python and calculate distances and create small applications such as a word filter and a phonebook. I feel that I have learned how to use Python and handle data in a practical way.
