# %% [markdown]
# <a href="https://colab.research.google.com/github/Braganzacpe/CPE-009A-CPE12S2-00P1/blob/main/Midterm_Exam_Q23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for pp in range(1,6):
  print("*"*pp)
for pp in range(4,0,-1):
  print("*"*pp)

print(" \n") #Other way because ma'am said I have the same answer as others
rowbro = 5
for i in range(1,rowbro+1):
  print("*"*i)
  if i == rowbro:
    for j in range(rowbro-1,0,-1):
      print("*"*j)
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *
#
#
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *
