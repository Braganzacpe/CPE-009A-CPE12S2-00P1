# %% [markdown]
# <a href="https://colab.research.google.com/github/Braganzacpe/CPE-009A-CPE12S2-00P1/blob/main/Jupyter_Notebook_OOP_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# <center>
#
# **Technological Institute of the Philippines**<br>
# Computer Engineering Department<br>
# Quezon city Campus</center>
#
# ---
# <center><h4> Hands-on Activity 2.1 | Literals and Variables  </h4></center>
#
# ---
# <center>
#
# | Course: CPE 009 | Program: BSCpE |
# |--- | --- |
# | **Course Title**: Object Oriented Programming | **Date Performed:** 1/15/2025|
# | **Section**: CPE12S2  | **Date Submitted:** 1/15/2025 |
# | **Student Name** Ralph Angelov F. Braganza:  | **Instructor's Name:** Ms. Sayo |
# </center>

# %% [markdown]
# **Objective/s of the activity:**
#
# 1.   Implement literals and variables in a python program.
#
# **Intended Learning Outcome:**
#
# 1.   Write a simple program implementing literals and variables.
# 2.   Use comments and identify keywords from identifiers created by users.
#
# **Discussion:**
#
# Discuss the use of variables, constants and literals in a python program.
#
# **Materials and Equipment:**
#
# 1.   List item
# 2.   List item
#
# **Procedure:**
#
# 1.   List item
# 2.   List item

# %% [markdown]
# Tasks:
# A teacher wants to calculate the final grade in a CpE course and want to write it in a python program. The following are the requirements:
#
# 1. PRELIM GRADE = 50% Prelim Exam + 50% Prelim Class Standing (CS)
# 2. PRELIM CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
# 3. MIDTERM GRADE = 1/3 of PRELIM GRADE + 2/3 of (50% Midterm Exam + 50% Midterm Class Standing (CS))
# 4. MIDTERM CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
# 5. FINAL GRADE = 1/3 of MIDTERM GRADE + 2/3 of (50% Final Exam + 50% Final Class Standing (CS))
# 6. FINAL CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
# 7. HOAs, Quizzes and Assignments are inputted as average of all submissions and are out of 100%.
# 8. Major exams are inputted out of 100%.
# 9. Show the codes that successfully run the program.
# 10. Provide comments or documentation strings for your program.

# %%
student_count = 1 #student counter
while student_count <= 3: #loops only 3 times
  print("")
  print("Student ",student_count)
  print("PRELIM")
  #PRELIM CLASS STANDING
  PHOA = float(input("Enter Prelim Hands-on Activity: "))
  PQUIZ = float(input("Enter Prelim Quiz: "))
  PAS = float(input("Enter Prelim Assignment: "))
  PCS = PHOA*.5 + PQUIZ*.3 + PAS*.2
  print("Prelim CS is: ", PCS)

  #PRELIM EXAM
  PEX = float(input("Enter Prelim Exam: "))

  #PRELIM GRADE
  PG = PEX*.5 + PCS*.5
  print("Prelim Grade is: ", "%.2f" % PG)
  #-----------------------------------------------
  print("")
  print("MIDTERM")
  #MIDTERM CLASS STANDING
  MHOA = float(input("Enter Midterm Hands-on Activity: "))
  MQUIZ = float(input("Enter Midterm Quiz: "))
  MAS = float(input("Enter Midterm Assignment: "))
  MCS = MHOA*.5 + MQUIZ*.3 + MAS*.2
  print("Midterm CS is: ", MCS)

  #MIDTERM EXAM
  MEX = float(input("Enter Midterm Exam: "))

  #MIDTERM GRADE
  MG = 1/3*PG + 2/3*(MEX*.5 + MCS*.5)
  print("Midterm Grade is: ", "%.2f" % MG)
  #-----------------------------------------------
  print("")
  print("FINALS")
  #FINAL CLASS STANDING
  FHOA = float(input("Enter Final Hands-on Activity: "))
  FQIZ = float(input("Enter Final Quiz: "))
  FAS = float(input("Enter Final Assignment: "))
  FCS = FHOA*.5 + FQIZ*.3 + FAS*.2
  print("Final CS is: ", FCS)

  #FINAL EXAM
  FEX = float(input("Enter Final Exam: "))

  #FINAL GRADE
  FG = 1/3*MG + 2/3*(FEX*.5 + FCS*.5)
  print("Final Grade is: ", "%.2f" % FG)
  student_count += 1
# Out:
# Student  1
# PRELIM
# Enter Prelim Hands-on Activity: 88
# Enter Prelim Quiz: 75
# Enter Prelim Assignment: 88
# Prelim CS is:  84.1
# Enter Prelim Exam: 88
# Prelim Grade is:  86.05
#
# MIDTERM
# Enter Midterm Hands-on Activity: 76
# Enter Midterm Quiz: 87
# Enter Midterm Assignment: 89
# Midterm CS is:  81.89999999999999
# Enter Midterm Exam: 67
# Midterm Grade is:  78.32
#
# FINALS
# Enter Final Hands-on Activity: 79
# Enter Final Quiz: 68
# Enter Final Assignment: 99
# Final CS is:  79.7
# Enter Final Exam: 68
# Final Grade is:  75.34
#
# Student  2
# PRELIM
# Enter Prelim Hands-on Activity: 86
# Enter Prelim Quiz: 57
# Enter Prelim Assignment: 68
# Prelim CS is:  73.69999999999999
# Enter Prelim Exam: 68
# Prelim Grade is:  70.85
#
# MIDTERM
# Enter Midterm Hands-on Activity: 68
# Enter Midterm Quiz: 57
# Enter Midterm Assignment: 68
# Midterm CS is:  64.69999999999999
# Enter Midterm Exam: 57
# Midterm Grade is:  64.18
#
# FINALS
# Enter Final Hands-on Activity: 68
# Enter Final Quiz: 57
# Enter Final Assignment: 99
# Final CS is:  70.89999999999999
# Enter Final Exam: 57
# Final Grade is:  64.03
#
# Student  3
# PRELIM
# Enter Prelim Hands-on Activity: 57
# Enter Prelim Quiz: 97
# Enter Prelim Assignment: 68
# Prelim CS is:  71.19999999999999
# Enter Prelim Exam: 75
# Prelim Grade is:  73.10
#
# MIDTERM
# Enter Midterm Hands-on Activity: 68
# Enter Midterm Quiz: 97
# Enter Midterm Assignment: 75
# Midterm CS is:  78.1
# Enter Midterm Exam: 79
# Midterm Grade is:  76.73
#
# FINALS
# Enter Final Hands-on Activity: 6
# Enter Final Quiz: 68
# Enter Final Assignment: 68
# Final CS is:  37.0
# Enter Final Exam: 99
# Final Grade is:  70.91

# %% [markdown]
# **Supplementary Activity**:
#
#
# Test 3 students from the program you created.
#
# 1. The program should show the name of the student, the PRELIM, MIDTERM and FINAL grades.
# 2. Convert the final grade into the T.I.P.s numerical grade. Please refer to the grading system.

# %%
student_count = 0
while student_count < 3:
  student_name = input("Enter Student Name: ")
  PG = float(input("Enter Prelim Grade: "))
  MG = float(input("Enter Midterm Grade: "))
  FG = float(input("Enter Final Grade: "))
  print("Student Name: {student_name}")
  print("  Prelim Grade: ", PG)
  print("  Midterm Grade: ", MG)
  print("  Final Grade: ", FG)
  if 99 <= FG <= 100:
    print("T.I.P.s Grade: 1.00")
  elif 95 < FG < 99:
    print("T.I.P.s Grade: 1.25")
  elif 92 < FG < 96:
    print("T.I.P.s Grade: 1.50")
  elif 89 < FG < 93:
    print("T.I.P.s Grade: 1.75")
  elif 86 < FG < 90:
    print("T.I.P.s Grade: 2.00")
  elif 83 < FG < 87:
    print("T.I.P.s Grade: 2.25")
  elif 80 < FG < 84:
    print("T.I.P.s Grade: 2.50")
  elif 77 < FG < 81:
    print("T.I.P.s Grade: 2.75")
  elif 74 < FG < 78:
    print("T.I.P.s Grade: 3.00")
  else:
    print("T.I.P.s Grade: 5.00")
  student_count += 1
# Out:
# Enter Student Name: Christine
# Enter Prelim Grade: 87
# Enter Midterm Grade: 86
# Enter Final Grade: 99
# Student Name: {student_name}
#   Prelim Grade:  87.0
#   Midterm Grade:  86.0
#   Final Grade:  99.0
# T.I.P.s Grade: 1.00
# Enter Student Name: Ralph
# Enter Prelim Grade: 88
# Enter Midterm Grade: 77
# Enter Final Grade: 89
# Student Name: {student_name}
#   Prelim Grade:  88.0
#   Midterm Grade:  77.0
#   Final Grade:  89.0
# T.I.P.s Grade: 2.00
# Enter Student Name: Kenji
# Enter Prelim Grade: 67
# Enter Midterm Grade: 67
# Enter Final Grade: 78
# Student Name: {student_name}
#   Prelim Grade:  67.0
#   Midterm Grade:  67.0
#   Final Grade:  78.0
# T.I.P.s Grade: 2.75

# %% [markdown]
# **Questions**: (write your answers in blue font color and questions in black)
#
# 1.   List item
# 2.   List item

# %% [markdown]
# **Conclusion**:
# (conclusion must be based from the objective and answers whether you attained the objective/s or not and a brief explanation how you attained it)

# %%
PHOA = float(input("Enter Hands-on Activity grade: "))
PQUIZ = float(input("Enter Prelim Quiz grade: "))
PAS = float(input("Enter Prelim Assignment grade: "))
PCS = PHOA*.5 + PQUIZ*.3 + PAS*.2
print("Prelim CS is: ", PCS)
PEX = float(input("Enter Prelim Exam grade: "))
PG = PEX*.5 + PCS*.5
print("Prelim Grade is: ", "%.2f" % PG)
# Out:
# Enter Hands-on Activity grade: 100
# Enter Prelim Quiz grade: 85
# Enter Prelim Assignment grade: 50
# Prelim CS is:  85.5
# Enter Prelim Exam grade: 75
# Prelim Grade is:  80.25
